# %%
import pandas as pd
import numpy as np
import os
flu_data = "Resources/Outpatient_Flu_Outcome_California.csv"
flu_df = pd.read_csv(flu_data)
flu_df.head().style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_cfe7749e_4c7f_11ea_9537_1c1bb56c094d" ><thead>    <tr>        <th class="col_heading level0 col0" >season</th>        <th class="col_heading level0 col1" >date_code</th>        <th class="col_heading level0 col2" >weekending</th>        <th class="col_heading level0 col3" >region</th>        <th class="col_heading level0 col4" >Respiratory_Virus</th>        <th class="col_heading level0 col5" >Number_Positive</th>        <th class="col_heading level0 col6" >Specimens_Tested</th>        <th class="col_heading level0 col7" >Percent_Positive</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_cfe7749e_4c7f_11ea_9537_1c1bb56c094drow0_col0" class="data row0 col0" >2009-2010</td>
#                         <td id="T_cfe7749e_4c7f_11ea_9537_1c1bb56c094drow0_col1" class="data row0 col1" >200940</td>
# ...

# %%
flu2_df = flu_df.drop(columns=['date_code'])

# %%
flu2_df.rename(columns={"season": "Season", "weekending": "Weekending", "region":"Region"})
# Out:
#           Season  Weekending                Region          Respiratory_Virus  \
# 0      2009-2010  10/10/2009              Bay Area                Influenza_A
# 1      2009-2010  10/10/2009              Bay Area                Influenza_B
# 2      2009-2010  10/10/2009              Bay Area            Total_Influenza
# 3      2009-2010  10/10/2009              Bay Area                        RSV
# 4      2009-2010  10/10/2009            California                Influenza_A
# ...          ...         ...                   ...                        ...
# 36174  2017-2018   9/29/2018  Upper/Lower Southern            Parainfluenza_2
# 36175  2017-2018   9/29/2018  Upper/Lower Southern            Parainfluenza_3
# 36176  2017-2018   9/29/2018  Upper/Lower Southern            Parainfluenza_4
# 36177  2017-2018   9/29/2018  Upper/Lower Southern  Parainfluenza_UnknownType
# 36178  2017-2018   9/29/2018  Upper/Lower Southern        Total_Parainfluenza
#
# ...

# %%
flu2_df.groupby(flu2_df["Weekending"].dt.month).sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Weekending'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-acfbb3c4da0b> in <module>
# ...
